# %%
import pandas as pd 
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt 
dataset=pd.read_csv("C:\\Users\\Yashwanth Nani\\Desktop\\creditcard1.csv") 
dataset
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
creditcard=dataset 
print(creditcard.shape)
# Out:
# (284807, 31)

# %%
print(creditcard.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
creditcard["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.set_style("whitegrid") 
sns.FacetGrid(creditcard,hue="Class",height=6).map(plt.scatter,"Time","Amount").add_legend 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set_style("whitegrid") 
sns.FacetGrid(creditcard,hue="Class",height=6).map(plt.scatter,"Amount","Time").add_legend()
plt.show()

# %%
FilteredData=creditcard[["Time","Amount","Class"]] 
FilteredData
# Out:
#             Time  Amount  Class
# 0            0.0  149.62      0
# 1            0.0    2.69      0
# 2            1.0  378.66      0
# 3            1.0  123.50      0
# 4            2.0   69.99      0
# ...          ...     ...    ...
# 284802  172786.0    0.77      0
# 284803  172787.0   24.79      0
# 284804  172788.0   67.88      0
# 284805  172788.0   10.00      0
# 284806  172792.0  217.00      0
#
# [284807 rows x 3 columns]

# %%
print(FilteredData.shape)
# Out:
# (284807, 3)

# %%
FilteredData["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
plt.close(); 
sns.set_style("whitegrid")
sns.pairplot(FilteredData,hue="Class",height=5)
plt.show()

# %%
countLess=0 
countMore=0 
for i in range(284806): 
 if(FilteredData.iloc[i]["Amount"]<2500): 
   countLess=countLess+1 
 else: 
   countMore=countMore+1 
print(countLess) 
print(countMore)
# Out:
# 284357
# 449

# %%
percentage=(countLess/284807)*100 
percentage
# Out:
# 99.84199826549207

# %%
class0=0 
class1=0 
for i in range(284806): 
 if(FilteredData.iloc[i]["Amount"]<2500): 
   if(FilteredData.iloc[i]["Class"]==0): 
    class0=class0+1 
   else: 
    class1=class1+1 
print(class0) 
print(class1)
# Out:
# 283865
# 492

# %%
FilteredData["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
creditcard_genuine=FilteredData.loc[FilteredData["Class"]==0] 
creditcard_fraud=FilteredData.loc[FilteredData["Class"]==1] 
plt.plot(creditcard_genuine["Time"],np.zeros_like(creditcard_genuine["Time"]),"o") 
plt.plot(creditcard_fraud["Time"],np.zeros_like(creditcard_fraud["Time"]),"o") 
plt.show()

# %%
plt.plot(creditcard_genuine["Amount"],np.zeros_like(creditcard_genuine["Amount"]),
"o") 
plt.plot(creditcard_fraud["Amount"],np.zeros_like(creditcard_fraud["Amount"]),"o") 
plt.show()

# %%
sns.FacetGrid(FilteredData,hue="Class",height=10).map(sns.distplot,"Time").add_legend() 
plt.show()
# Out:
# C:\Users\Yashwanth Nani\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Yashwanth Nani\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(FilteredData,hue="Class",height=10).map(sns.distplot,"Amount").add_legend() 
plt.show()
# Out:
# C:\Users\Yashwanth Nani\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Yashwanth Nani\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Means:") 
print("Mean of transaction amount of genuine transaction: ",np.mean(creditcard_genuine["Amount"])) 
print("Mean of transaction amount of fraud transaction: ",np.mean(creditcard_fraud["Amount"]))
# Out:
# Means:
# Mean of transaction amount of genuine transaction:  88.29102242225574
# Mean of transaction amount of fraud transaction:  122.21132113821133

# %%
print("Standard Deviation:") 
print("std-deviation of transaction amount of genuine transaction: ",np.std(creditcard_genuine["Amount"])) 
print("std-deviation of transaction amount of fraud transaction: ",np.std(creditcard_fraud["Amount"]))
# Out:
# Standard Deviation:
# std-deviation of transaction amount of genuine transaction:  250.1046523874637
# std-deviation of transaction amount of fraud transaction:  256.42229861324483

# %%
print("Median:") 
print("Median of transaction amount of genuine transaction: ",np.median(creditcard_genuine["Amount"])) 
print("Median of transaction amount of fraud transaction: ",np.median(creditcard_fraud["Amount"]))
# Out:
# Median:
# Median of transaction amount of genuine transaction:  22.0
# Median of transaction amount of fraud transaction:  9.25

# %%
print("\nQuantiles:") 
print(np.percentile(creditcard_genuine["Amount"],np.arange(0,100,25))) 
print(np.percentile(creditcard_fraud["Amount"],np.arange(0,100,25)))
# Out:
# Quantiles:
# [ 0.    5.65 22.   77.05]
# [  0.     1.     9.25 105.89]

# %%
X=dataset.iloc[:,:-1].values 
y=dataset.iloc[:,30].values 
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20) 
from sklearn.preprocessing import StandardScaler 
scaler=StandardScaler() 
scaler.fit(X_train) 
X_train=scaler.transform(X_train) 
X_test=scaler.transform(X_test) 
from sklearn.neighbors import KNeighborsClassifier 
classifier=KNeighborsClassifier(n_neighbors=5) 
classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("length of X_train is: {X_train}".format(X_train=len(X_train))) 
print("length of X_test is: {X_test}".format(X_test=len(X_test))) 
print("length of y_train is: {y_train}".format(y_train=len(y_train))) 
print("length of y_test is: {y_test}".format(y_test=len(y_test)))
# Out:
# length of X_train is: 227845
# length of X_test is: 56962
# length of y_train is: 227845
# length of y_test is: 56962

# %%
y_pred=classifier.predict(X_test) 
print("Actual values:",y_test,"Predicted values:",y_pred)
# Out:
# Actual values: [0 0 0 ... 0 0 0] Predicted values: [0 0 0 ... 0 0 0]

# %%
print("no of actual values are: {y_test}".format(y_test=len(y_test))) 
df1=pd.DataFrame(y_test,columns=["Class"]) 
df1["Class"].value_counts()
# Out:
# no of actual values are: 56962
# 0    56869
# 1       93
# Name: Class, dtype: int64

# %%
print("no of predicted values are: {y_pred}".format(y_pred=len(y_pred))) 
df=pd.DataFrame(y_pred,columns=["Class"]) 
df["Class"].value_counts()
# Out:
# no of predicted values are: 56962
# 0    56884
# 1       78
# Name: Class, dtype: int64

# %%
TN=0 
FP=0 
TP=0 
FN=0 
for i in range(len(y_pred)): 
 if y_test[i]==y_pred[i]==1: 
   TP+=1 
 if y_pred[i]==1 and y_test[i]!=y_pred[i]: 
   FP+=1 
 if y_test[i]==y_pred[i]==0: 
   TN+=1 
 if y_pred[i]==0 and y_test[i]!=y_pred[i]: 
   FN+=1 
print("true positive values are {}".format(TP)) 
print("false positive values are {}".format(FP)) 
print("true negative values are {}".format(TN)) 
print("false negative values are {}".format(FN))
# Out:
# true positive values are 70
# false positive values are 8
# true negative values are 56861
# false negative values are 23

# %%
from sklearn.metrics import confusion_matrix 
LABELS=["Normal","Fraud"]
conf_matrix=confusion_matrix(y_test,y_pred) 
plt.figure(figsize=(12,12)) 
sns.heatmap(conf_matrix,xticklabels=LABELS,yticklabels=LABELS,annot=True,fmt="d") 
plt.title("confusion matrix") 
plt.ylabel("true class") 
plt.xlabel("predicted label") 
plt.show()

# %%
from sklearn.metrics import classification_report,accuracy_score 
from sklearn.metrics import precision_score,recall_score 
from sklearn.metrics import f1_score,matthews_corrcoef 
from sklearn.metrics import confusion_matrix 
n_errors=(y_pred!=y_test).sum() 
print("the model used is KNN classifier") 
print("\n") 
print("no. of outliers are",n_errors) 
acc=accuracy_score(y_test,y_pred)
print("the accuracy of this algorithm is {}".format(acc)) 
prec=precision_score(y_test,y_pred) 
print("the precision or positive predicted value is{}".format(prec)) 
rec=recall_score(y_test,y_pred) 
print("the recall or true positive rate is {}".format(rec))
f1=f1_score(y_test,y_pred) 
print("the f1 score is {}".format(f1)) 
mcc=matthews_corrcoef(y_test,y_pred) 
print("the Matthews Correlation coefficient is {}".format(mcc))
# Out:
# the model used is KNN classifier
#
#
# no. of outliers are 31
# the accuracy of this algorithm is 0.9994557775359011
# the precision or positive predicted value is0.8974358974358975
# the recall or true positive rate is 0.7526881720430108
# the f1 score is 0.8187134502923976
# the Matthews Correlation coefficient is 0.8216196567489678

# %%
tnr=TN/(TN+TP) 
print("the specificity or true negative rate is {}".format(tnr)) 
npv=TN/(TN+FN) 
print("the negative predictive value is {}".format(npv))
fnr=FN/(FN+TP) 
print("the false negative rate is {}".format(fnr)) 
fdr=FN/(FP+TP) 
print("the false discovery rate is {}".format(fdr))
# Out:
# the specificity or true negative rate is 0.9987704414115333
# the negative predictive value is 0.9995956683777513
# the false negative rate is 0.24731182795698925
# the false discovery rate is 0.2948717948717949

# %%
ACC=(TP+TN)/(TP+FP+FN+TN)*100 
ACCU=round(ACC,3) 
print("Overall Accuracy by using KNN Classifier is {}%".format(ACCU))
# Out:
# Overall Accuracy by using KNN Classifier is 99.946%
